// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 5

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Book в C#, который будет представлять информацию о
// книгах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// ### Требования к базовому классу Book:
// • Атрибуты: Название (Title), Автор (Author), Год издания (YearOfPublication).
//
// • Методы:
//
//     • GetInfo(): метод для получения информации о книге в виде строки.
//     • Read(): метод для вывода сообщения о чтении книги.
//     • Borrow(): метод для вывода сообщения о выдаче книги на чтение.
//
// ### Требования к производным классам:
// 1. Учебник (Textbook): Должен содержать дополнительные атрибуты, такие как
// Предмет (Subject). Метод Read() должен быть переопределен для
// добавления информации о предмете при чтении учебника.
// 2. Художественная литература (Fiction): Должен содержать дополнительные
// атрибуты, такие как Жанр (Genre). Метод Borrow() должен быть
// переопределен для добавления информации о жанре при выдаче книги на
// чтение.
// 3. Научная литература (ScientificLiterature) (если требуется третий класс):
// Должен содержать дополнительные атрибуты, такие как Область науки
// (FieldOfScience). Метод GetInfo() должен быть переопределен для включения
// информации об области науки в описании книги.
//
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic; // для List

public class Book
{
    public string Title { get; set; }
    public string Author { get; set; }
    public int YearOfPublication { get; set; }

    public Book(string title, string author, int yearOfPublication)
    {
        Title = title;
        Author = author;
        YearOfPublication = yearOfPublication;
    }

    public virtual string GetInfo() => $"Книга: '{Title}', Автор: {Author}, Год: {YearOfPublication}";
    public virtual void Read() => Console.WriteLine($"Читаем книгу '{Title}'...");
    public virtual void Borrow() => Console.WriteLine($"Книга '{Title}' выдана на чтение.");
}

public class Textbook : Book
{
    public string Subject { get; set; }

    public Textbook(string title, string author, int year, string subject)
        : base(title, author, year) => Subject = subject;

    public override void Read()
        => Console.WriteLine($"Читаем учебник по предмету '{Subject}': '{Title}'...");
}

public class Fiction : Book
{
    public string Genre { get; set; }

    public Fiction(string title, string author, int year, string genre)
        : base(title, author, year) => Genre = genre;

    public override void Borrow()
        => Console.WriteLine($"Выдана художественная книга (Жанр: {Genre}) — '{Title}'.");
}

public class ScientificLiterature : Book
{
    public string FieldOfScience { get; set; }

    public ScientificLiterature(string title, string author, int year, string fieldOfScience)
        : base(title, author, year) => FieldOfScience = fieldOfScience;

    public override string GetInfo()
        => $"{base.GetInfo()}, Область науки: {FieldOfScience}";
}

// добавлен класс Reader — читатель
public class Reader
{
    public string Name { get; set; }
    private List<Book> borrowedBooks = new List<Book>();

    public Reader(string name) => Name = name;

    // Взаимодействие: читатель берет книгу
    public void BorrowBook(Book book)
    {
        borrowedBooks.Add(book);
        Console.WriteLine($"{Name} взял книгу: '{book.Title}'");
        book.Borrow(); // вызов метода книги (взаимодействие)
    }

    //взаимодействие: читатель читает книгу
    public void ReadBook(Book book)
    {
        Console.WriteLine($"{Name} читает...");
        book.Read();
    }
}

// добавлен класс Library — библиотека
public class Library
{
    public string Name { get; set; }
    private List<Book> books = new List<Book>();

    public Library(string name) => Name = name;

    public void AddBook(Book book) => books.Add(book);

    // взаимодействие: библиотека выдает книгу читателю
    public void LendBook(Book book, Reader reader)
    {
        if (!books.Contains(book))
        {
            Console.WriteLine($"Книги '{book.Title}' нет в библиотеке!");
            return;
        }
        books.Remove(book);
        Console.WriteLine($"Библиотека '{Name}' выдает книгу '{book.Title}' читателю {reader.Name}");
        reader.BorrowBook(book);
    }
}

var library = new Book[]
{
    new Textbook("Алгебра 9 класс", "А.Г. Мордкович", 2020, "Математика"),
    new Fiction("Мастер и Маргарита", "М.А. Булгаков", 1967, "Роман"),
    new ScientificLiterature("Краткая история времени", "Стивен Хокинг", 1988, "Астрофизика")
};

foreach (var book in library)
{
    Console.WriteLine(book.GetInfo());
    book.Read();
    book.Borrow();
    Console.WriteLine("--------------------------------------------------");
}

// добавлена демонстрация взаимодействия объектов
Console.WriteLine("\n=== ВЗАИМОДЕЙСТВИЕ ОБЪЕКТОВ ===");
var lib = new Library("Городская библиотека");
foreach (var b in library) lib.AddBook(b);

var reader = new Reader("Иван");
lib.LendBook(library[1], reader); // библиотека - читатель - книга
reader.ReadBook(library[1]);      // читатель - книга
// Out:
// Книга: 'Алгебра 9 класс', Автор: А.Г. Мордкович, Год: 2020
// Читаем учебник по предмету 'Математика': 'Алгебра 9 класс'...
// Книга 'Алгебра 9 класс' выдана на чтение.
// --------------------------------------------------
// Книга: 'Мастер и Маргарита', Автор: М.А. Булгаков, Год: 1967
// Читаем книгу 'Мастер и Маргарита'...
// Выдана художественная книга (Жанр: Роман) — 'Мастер и Маргарита'.
// --------------------------------------------------
// Книга: 'Краткая история времени', Автор: Стивен Хокинг, Год: 1988, Область науки: Астрофизика
// Читаем книгу 'Краткая история времени'...
// Книга 'Краткая история времени' выдана на чтение.
// --------------------------------------------------
//
// === ВЗАИМОДЕЙСТВИЕ ОБЪЕКТОВ ===
// Библиотека 'Городская библиотека' выдает книгу 'Мастер и Маргарита' читателю Иван
// Иван взял книгу: 'Мастер и Маргарита'
// Выдана художественная книга (Жанр: Роман) — 'Мастер и Маргарита'.
// Иван читает...
// Читаем книгу 'Мастер и Маргарита'...
